# %%
from pathlib import Path
from dotenv import load_dotenv
import os

BASE_DIR = "D:/AI-2025/Systems/enterprise-knowledge-agent/backend/.env"
load_dotenv(BASE_DIR)

api_key = os.getenv("GOOGLE_API_KEY")
if not api_key:
    raise RuntimeError("GOOGLE_API_KEY not found in environment.")

# %%
mistral_api_key = os.getenv("MISTRAL_API_KEY")

# %%
import json
from mistralai import Mistral

# %%
# Parsing the result
result = json.loads(response.choices[0].message.content)

# %%
print(f"Summary: {result['summary']}")
# Out:
# Summary: LangGraph is a revolutionary orchestration framework that models agent and multi-agent workflows as cyclic graphs, enabling stateful, reflective, and adaptive AI applications. It builds on LangChain's foundation, introducing cycles to overcome the limitations of linear chains and directed acyclic graphs, allowing for more complex and autonomous agent behaviors.

# %%
result
# Out:
# {'summary': "LangGraph is a revolutionary orchestration framework that models agent and multi-agent workflows as cyclic graphs, enabling stateful, reflective, and adaptive AI applications. It builds on LangChain's foundation, introducing cycles to overcome the limitations of linear chains and directed acyclic graphs, allowing for more complex and autonomous agent behaviors.",
#  'topics': 'AI workflows, LangGraph, cyclic graphs, agent orchestration, LangChain',
#  'keywords': 'LangGraph, AI workflows, cyclic graphs, agent orchestration, LangChain'}

# %%
print(f"Keywords: {result['keywords']}")
print(f"topics: {result['topics']}")
# Out:
# Keywords: LangGraph, AI workflows, cyclic graphs, agent orchestration, LangChain
# topics: AI workflows, LangGraph, cyclic graphs, agent orchestration, LangChain

# %%
from langchain_core.messages import HumanMessage, AIMessage, ToolMessage
state =  {'messages': [HumanMessage(content="what's the admin name", additional_kwargs={}, 
response_metadata={}, id='ddb29061-23a8-400d-ab47-e51b306b2e69'),
 AIMessage(content="Tool Used: SQL\nQuery (if SQL): SELECT u.name FROM users u JOIN roles r ON u.role_id = r.id WHERE r.name = 'admin'\nFinal Answer: The admin name is Sayed.", 
 additional_kwargs={}, response_metadata={}, id='68ba7a3c-add3-4cf2-b6f2-d0fbea070e46', tool_calls=[], invalid_tool_calls=[]),
  HumanMessage(content='who are the viewers ', additional_kwargs={}, response_metadata={}, id='58911a79-0fd5-4fe1-886a-ae052fdbdd80'),
   AIMessage(content="Tool Used: SQL\nQuery (if SQL): SELECT u.name FROM users u JOIN roles r ON u.role_id = r.id WHERE r.name = 'viewer'\nFinal Answer: The viewers are: Alice, Bob, Charlie.", additional_kwargs={}, response_metadata={}, id='3d38df1a-0b70-480e-9c7b-3f200cda9aee', tool_calls=[], invalid_tool_calls=[]),
    HumanMessage(content='who are the viewers ', additional_kwargs={}, response_metadata={}, id='a6a0d4d1-750d-475d-b82a-b6b6e37f32b3'),
     AIMessage(content="Tool Used: SQL\nQuery (if SQL): SELECT u.name FROM users u JOIN roles r ON u.role_id = r.id WHERE r.name = 'viewer'\nFinal Answer: The viewers are: Alice, Bob, Charlie.", additional_kwargs={}, response_metadata={}, id='3345f6f2-34dd-46b3-85ab-00d85d872a7f', tool_calls=[], invalid_tool_calls=[]),
      HumanMessage(content='who are the viewers ', additional_kwargs={}, response_metadata={}, id='6a34c758-7379-4e9a-a187-c9973a97f0d4'),
       AIMessage(content="Tool Used: SQL\nQuery (if SQL): SELECT u.name FROM users u JOIN roles r ON u.role_id = r.id WHERE r.name = 'viewer'\nFinal Answer: The viewers are: Alice, Bob, Charlie.", additional_kwargs={}, response_metadata={}, id='4e481dcb-6c53-4ac6-94c3-c246730e65ad', tool_calls=[], invalid_tool_calls=[]),
        HumanMessage(content='who are the viewers', additional_kwargs={}, response_metadata={}, id='ce62f61e-8643-4065-adf9-f46cf8dd6a4a'),
         AIMessage(content="Tool Used: SQL\nQuery (SQL): SELECT u.name FROM users u JOIN roles r ON u.role_id = r.id WHERE r.name = 'viewer'\nFinal Answer: The viewers are: Ayman, Ahemd.", additional_kwargs={}, response_metadata={}, id='93f585d1-b522-49f6-b941-7dae91a7f45c', tool_calls=[], invalid_tool_calls=[]),
          HumanMessage(content='list all system users with role name ', additional_kwargs={}, response_metadata={}, id='fa46234e-c3ab-4293-802f-96d6cd211b05'), 
          AIMessage(content='', additional_kwargs={'function_call': {'name': 'query_db', 'arguments': '{"sql": "SELECT u.name AS user_name, r.name AS role_name FROM users u JOIN roles r ON u.role_id = r.id"}'}, '__gemini_function_call_thought_signatures__': {'958a67fc-8044-4b6f-becb-890487f1cfd7': '...'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019cc5b6-60f5-7da3-bafc-af10d1e1f319-0', tool_calls=[{'name': 'query_db', 'args': {'sql': 'SELECT u.name AS user_name, r.name AS role_name FROM users u JOIN roles r ON u.role_id = r.id'}, 'id': '958a67fc-8044-4b6f-becb-890487f1cfd7', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1574, 'output_tokens': 118, 'total_tokens': 1692, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 72}}), 
          ToolMessage(content="Query returned 5 row(s):\nRow 1: user_name='Sayed', role_name='admin'\nRow 2: user_name='Ali', role_name='analyst'\nRow 3: user_name='Mohamed', role_name='analyst'\nRow 4: user_name='Ahemd', role_name='viewer'\nRow 5: user_name='Ayman', role_name='viewer'", name='query_db', id='7f1ef881-1549-4a80-abb9-8452dbf7479a', tool_call_id='958a67fc-8044-4b6f-becb-890487f1cfd7')], 'user_role': 'admin'}

# %%
state["messages"][-2:]
# Out:
# [AIMessage(content='', additional_kwargs={'function_call': {'name': 'query_db', 'arguments': '{"sql": "SELECT u.name AS user_name, r.name AS role_name FROM users u JOIN roles r ON u.role_id = r.id"}'}, '__gemini_function_call_thought_signatures__': {'958a67fc-8044-4b6f-becb-890487f1cfd7': '...'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019cc5b6-60f5-7da3-bafc-af10d1e1f319-0', tool_calls=[{'name': 'query_db', 'args': {'sql': 'SELECT u.name AS user_name, r.name AS role_name FROM users u JOIN roles r ON u.role_id = r.id'}, 'id': '958a67fc-8044-4b6f-becb-890487f1cfd7', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1574, 'output_tokens': 118, 'total_tokens': 1692, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 72}}),
# ...

# %%
last_message = state["messages"][-1]
last_message
# Out:
# ToolMessage(content='Ayman Mohamed Abdallah\nAI Engineer\nayman.mohamed141163@el-eng.menofia.edu.eg/ne(+2) 01028771728/♀nednlinkedin.com/in/Ayman-Mohamed\n/gtbgithub.com/aymanmohamed043\nSummary\nAI Engineer skilled in Machine Learning, NLP, and LLM applications with hands-on experience in RAG\nsystems, sentiment analysis, and data-driven solutions using Python, LangChain, and Vector Database.\nStrong analytical thinker with a focus on practical implementation and continuous learning.\nEducation\nInformation Technology Institute (ITI)Jul 2025 � Nov 2025\n4-Month Intensive Code Camp � Full Stack Python\nMenoufia University2019 � 2024\nB.Sc. in Computer Science, Faculty of Menof Electronics Engineering\nGraduation Grade: Very Good\nExperience\nFloLabs R&D Robotics and AI TeamJan 2026 � Present\nMachine Learning Intern\n�Designed and deployed acontainerized backend architectureusing Docker Compose, orchestrat-\ning Django application and PostgreSQL database services.\n\n�Delivereddata-d
# ...

# %%
state["messages"][-3].content
# Out:
# 'what projects that ayman did?'

# %%
state2=  {'messages': [HumanMessage(content="what's the admin name", additional_kwargs={}, response_metadata={}, id='3345689a-eddc-458f-bb80-2809690e355b'), AIMessage(content="Tool Used: SQL\nQuery (if SQL): SELECT u.name FROM users u JOIN roles r ON u.role_id = r.id WHERE r.name = 'admin'\nFinal Answer: The admin name is Sayed.", additional_kwargs={}, response_metadata={}, id='07aef440-027b-4c07-9b5b-0b687ae24812', tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='who are the viewers ', additional_kwargs={}, response_metadata={}, id='ed58690d-9df9-4cf2-8fc0-92a2be64dc7e'), AIMessage(content="Tool Used: SQL\nQuery (if SQL): SELECT u.name FROM users u JOIN roles r ON u.role_id = r.id WHERE r.name = 'viewer'\nFinal Answer: The viewers are: Alice, Bob, Charlie.", additional_kwargs={}, response_metadata={}, id='93b42745-d82f-4551-9091-cab818f878dd', tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='who are the viewers ', additional_kwargs={}, response_metadata={}, id='d9e09fc0-bce8-464a-8a68-c1f1e309057e'), AIMessage(content="Tool Used: SQL\nQuery (if SQL): SELECT u.name FROM users u JOIN roles r ON u.role_id = r.id WHERE r.name = 'viewer'\nFinal Answer: The viewers are: Alice, Bob, Charlie.", additional_kwargs={}, response_metadata={}, id='1351fa51-f6ad-49bf-a236-f65697804abd', tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='who are the viewers ', additional_kwargs={}, response_metadata={}, id='b13f30f9-3a45-49a1-a97f-1855ca1655e8'), AIMessage(content="Tool Used: SQL\nQuery (if SQL): SELECT u.name FROM users u JOIN roles r ON u.role_id = r.id WHERE r.name = 'viewer'\nFinal Answer: The viewers are: Alice, Bob, Charlie.", additional_kwargs={}, response_metadata={}, id='2730d3e2-7810-47b2-a2ac-e7b3bc6af7f3', tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='who are the viewers', additional_kwargs={}, response_metadata={}, id='02256ec7-ddd0-49fd-b604-b17c303c1274'), AIMessage(content="Tool Used: SQL\nQuery (SQL): SELECT u.name FROM users u JOIN roles r ON u.role_id = r.id WHERE r.name = 'viewer'\nFinal Answer: The viewers are: Ayman, Ahemd.", additional_kwargs={}, response_metadata={}, id='21f91998-1a51-4cb4-9548-357114cf17dc', tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='what projects that ayman did?', additional_kwargs={}, response_metadata={}, id='5a6c4c24-5f10-47da-b1b4-6539bb560c52'), AIMessage(content=[{'type': 'text', 'text': 'Tool Used: Vector\nSource (Vector): Ayman_Mohamed_AI_Engineer_CV.pdf', 'extras': {'signature': '...'}}], additional_kwargs={'function_call': {'name': 'search_docs', 'arguments': '{"query": "Ayman Mohamed Abdallah\'s projects"}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019cc5a8-05dc-7792-8ff2-647149ab207e-0', tool_calls=[{'name': 'search_docs', 'args': {'query': "Ayman Mohamed Abdallah's projects"}, 'id': 'c8d6e8f1-a26f-423d-9d45-63825375d020', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1573, 'output_tokens': 161, 'total_tokens': 1734, 'input_token_details': {'cache_read': 794}, 'output_token_details': {'reasoning': 116}}), ToolMessage(content='Ayman Mohamed Abdallah\nAI Engineer\nayman.mohamed141163@el-eng.menofia.edu.eg/ne(+2) 01028771728/\u2640nednlinkedin.com/in/Ayman-Mohamed\n/gtbgithub.com/aymanmohamed043\nSummary\nAI Engineer skilled in Machine Learning, NLP, and LLM applications with hands-on experience in RAG\nsystems, sentiment analysis, and data-driven solutions using Python, LangChain, and Vector Database.\nStrong analytical thinker with a focus on practical implementation and continuous learning.\nEducation\nInformation Technology Institute (ITI)Jul 2025 � Nov 2025\n4-Month Intensive Code Camp � Full Stack Python\nMenoufia University2019 � 2024\nB.Sc. in Computer Science, Faculty of Menof Electronics Engineering\nGraduation Grade: Very Good\nExperience\nFloLabs R&D Robotics and AI TeamJan 2026 � Present\nMachine Learning Intern\n�Designed and deployed acontainerized backend architectureusing Docker Compose, orchestrat-\ning Django application and PostgreSQL database services.\n\n�Delivereddata-driven insightssupported by visualization dashboards and feature engineering.\nProjects\nProduct Reviews Analysis (FastAPI, LangChain, FAISS, LLMs, Selenium, Transformers)\n�Developed aproduct reviews analysis platformsupporting review visualization, summarization, and\nQ&A.\n�IntegratedLLMs and sentiment analysisfor deeper product insights.\n�Built a scalable backend withFastAPIand stored embeddings inFAISS.\nInteractive Q&A Chatbot (Google Gemini, Streamlit)\n�Built an AI-powered chatbot using Gemini with conversational memory.\n�Designed a dynamic UI in Streamlit for seamless multi-turn dialogue.\nArabic News RAG System (LangChain, FAISS, Gradio)\n�Developed a Retrieval-Augmented Generation system using the SANAD Dataset.\n�Implemented preprocessing, chunking, and FAISS vector storage.\n\nSentiment Analysis (Python, TensorFlow, LSTM)\n�Built an LSTM-based sentiment classifier using GloVe embeddings.\n�Implemented advanced NLP preprocessing and evaluation.\nTechnical Skills\nProgramming:Python, SQL, JavaScript\nMachine Learning:Scikit-learn, TensorFlow, PyTorch\nNLP & LLM:LangChain, LangGraph, Transformers, BERT, Vector Database\nBackend:Django, FastAPI\nData Tools:Pandas, NumPy, Matplotlib, Seaborn\nDatabases:PostgreSQL\nVersion Control:GitHub, Linux, Docker\nCertifications\nMachine Learning Specialization � Coursera (3 Courses)\nDeep Learning Specialization � Coursera (5 Courses) )\nLangChain with Retrieval-Augmented Generation (RAG) � Electro Pi)\nMathematics for Machine Learning and Data Science � Coursera\nGit and GitHub\nAdditional Information\nSoft Skills:Problem Solving, Analytical Thinking, Teamwork, Self-Learning, Communication\nLanguages:Arabic (Native), English (Upper-Intermediate)', name='search_docs', id='c7a4a34b-4fb1-4850-8abf-b2d450a85a6e', tool_call_id='c8d6e8f1-a26f-423d-9d45-63825375d020')], 'user_role': 'admin'}

# %%
state2["messages"][-2: ]
# Out:
# [AIMessage(content=[{'type': 'text', 'text': 'Tool Used: Vector\nSource (Vector): Ayman_Mohamed_AI_Engineer_CV.pdf', 'extras': {'signature': '...'}}], additional_kwargs={'function_call': {'name': 'search_docs', 'arguments': '{"query": "Ayman Mohamed Abdallah\'s projects"}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019cc5a8-05dc-7792-8ff2-647149ab207e-0', tool_calls=[{'name': 'search_docs', 'args': {'query': "Ayman Mohamed Abdallah's projects"}, 'id': 'c8d6e8f1-a26f-423d-9d45-63825375d020', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1573, 'output_tokens': 161, 'total_tokens': 1734, 'input_token_details': {'cache_read': 794}, 'output_token_details': {'reasoning': 116}}),
# ...

# %%
state3 = {'messages': [HumanMessage(content="what's the admin name", additional_kwargs={}, response_metadata={}, id='9f6a8376-1265-4d8b-a651-e6ba3e5af5a1'), AIMessage(content="Tool Used: SQL\nQuery (if SQL): SELECT u.name FROM users u JOIN roles r ON u.role_id = r.id WHERE r.name = 'admin'\nFinal Answer: The admin name is Sayed.", additional_kwargs={}, response_metadata={}, id='23754faf-801e-4e7b-886e-0518167aae44', tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='who are the viewers ', additional_kwargs={}, response_metadata={}, id='bcd2feb7-5e7e-4cb5-ac17-085023e7686b'), AIMessage(content="Tool Used: SQL\nQuery (if SQL): SELECT u.name FROM users u JOIN roles r ON u.role_id = r.id WHERE r.name = 'viewer'\nFinal Answer: The viewers are: Alice, Bob, Charlie.", additional_kwargs={}, response_metadata={}, id='8df0f597-5ee1-408d-98d4-45c2567a159b', tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='who are the viewers ', additional_kwargs={}, response_metadata={}, id='a5e9574b-8b06-40dc-be9c-4a0db48c1e25'), AIMessage(content="Tool Used: SQL\nQuery (if SQL): SELECT u.name FROM users u JOIN roles r ON u.role_id = r.id WHERE r.name = 'viewer'\nFinal Answer: The viewers are: Alice, Bob, Charlie.", additional_kwargs={}, response_metadata={}, id='1b4ceec3-e747-4994-bd59-d2bed098473c', tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='who are the viewers ', additional_kwargs={}, response_metadata={}, id='39f1103d-25e0-4fcd-bc82-e7facbe27d18'), AIMessage(content="Tool Used: SQL\nQuery (if SQL): SELECT u.name FROM users u JOIN roles r ON u.role_id = r.id WHERE r.name = 'viewer'\nFinal Answer: The viewers are: Alice, Bob, Charlie.", additional_kwargs={}, response_metadata={}, id='49563c7a-5558-46fe-a076-f0c57a601f80', tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='who are the viewers', additional_kwargs={}, response_metadata={}, id='7eeb4a3a-3a60-4fba-9ddf-e49164f8065a'), AIMessage(content="Tool Used: SQL\nQuery (SQL): SELECT u.name FROM users u JOIN roles r ON u.role_id = r.id WHERE r.name = 'viewer'\nFinal Answer: The viewers are: Ayman, Ahemd.", additional_kwargs={}, response_metadata={}, id='686e79d0-fa25-4cd3-81be-25dabcd7ce87', tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='which college ayman graduted from?', additional_kwargs={}, response_metadata={}, id='bd8bcd13-ddd1-4f46-9ee8-b3874bb0ebd0'), AIMessage(content='', additional_kwargs={'function_call': {'name': 'search_docs', 'arguments': '{"query": "Ayman Mohamed college"}'}, '__gemini_function_call_thought_signatures__': {'d56ec740-94d9-4e14-950a-07230397f6e1': '...'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019cc5cc-7337-7d71-ab64-1a12c2c05477-0', tool_calls=[{'name': 'search_docs', 'args': {'query': 'Ayman Mohamed college'}, 'id': 'd56ec740-94d9-4e14-950a-07230397f6e1', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1572, 'output_tokens': 110, 'total_tokens': 1682, 'input_token_details': {'cache_read': 794}, 'output_token_details': {'reasoning': 92}}), ToolMessage(content='Ayman Mohamed Abdallah\nAI Engineer\nayman.mohamed141163@el-eng.menofia.edu.eg/ne(+2) 01028771728/\u2640nednlinkedin.com/in/Ayman-Mohamed\n/gtbgithub.com/aymanmohamed043\nSummary\nAI Engineer skilled in Machine Learning, NLP, and LLM applications with hands-on experience in RAG\nsystems, sentiment analysis, and data-driven solutions using Python, LangChain, and Vector Database.\nStrong analytical thinker with a focus on practical implementation and continuous learning.\nEducation\nInformation Technology Institute (ITI)Jul 2025 � Nov 2025\n4-Month Intensive Code Camp � Full Stack Python\nMenoufia University2019 � 2024\nB.Sc. in Computer Science, Faculty of Menof Electronics Engineering\nGraduation Grade: Very Good\nExperience\nFloLabs R&D Robotics and AI TeamJan 2026 � Present\nMachine Learning Intern\n�Designed and deployed acontainerized backend architectureusing Docker Compose, orchestrat-\ning Django application and PostgreSQL database services.\n\nSentiment Analysis (Python, TensorFlow, LSTM)\n�Built an LSTM-based sentiment classifier using GloVe embeddings.\n�Implemented advanced NLP preprocessing and evaluation.\nTechnical Skills\nProgramming:Python, SQL, JavaScript\nMachine Learning:Scikit-learn, TensorFlow, PyTorch\nNLP & LLM:LangChain, LangGraph, Transformers, BERT, Vector Database\nBackend:Django, FastAPI\nData Tools:Pandas, NumPy, Matplotlib, Seaborn\nDatabases:PostgreSQL\nVersion Control:GitHub, Linux, Docker\nCertifications\nMachine Learning Specialization � Coursera (3 Courses)\nDeep Learning Specialization � Coursera (5 Courses) )\nLangChain with Retrieval-Augmented Generation (RAG) � Electro Pi)\nMathematics for Machine Learning and Data Science � Coursera\nGit and GitHub\nAdditional Information\nSoft Skills:Problem Solving, Analytical Thinking, Teamwork, Self-Learning, Communication\nLanguages:Arabic (Native), English (Upper-Intermediate)\n\nMachine Learning Intern\n�Designed and deployed acontainerized backend architectureusing Docker Compose, orchestrat-\ning Django application and PostgreSQL database services.\n�Implemented completeRESTful CRUD APIsfor core system entities with modular and scalable\nservice structure.\n�Built and optimizeddatabase schemasto support AI workflows and structured state persistence.\n�Contributed to the design of anagentic core system, defining controller�executor interactions and\nbackend state management.\nBritish Airways � Forage (Virtual Intern)Aug 2024\nData Science Trainee\n�Conductedexploratory data analysis (EDA)on customer review datasets to uncover behavioral\ntrends.\n�Designed and evaluated apredictive modelidentifying factors influencing purchasing decisions.\n�Delivereddata-driven insightssupported by visualization dashboards and feature engineering.\nProjects\nProduct Reviews Analysis (FastAPI, LangChain, FAISS, LLMs, Selenium, Transformers)', name='search_docs', id='939a91bc-962d-473e-a497-8c0a2e3fdaa6', tool_call_id='d56ec740-94d9-4e14-950a-07230397f6e1')], 'user_role': 'admin'}

# %%
state2['messages'][-3: ]
# Out:
# [HumanMessage(content='what projects that ayman did?', additional_kwargs={}, response_metadata={}, id='5a6c4c24-5f10-47da-b1b4-6539bb560c52'),
#  AIMessage(content=[{'type': 'text', 'text': 'Tool Used: Vector\nSource (Vector): Ayman_Mohamed_AI_Engineer_CV.pdf', 'extras': {'signature': '...'}}], additional_kwargs={'function_call': {'name': 'search_docs', 'arguments': '{"query": "Ayman Mohamed Abdallah\'s projects"}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019cc5a8-05dc-7792-8ff2-647149ab207e-0', tool_calls=[{'name': 'search_docs', 'args': {'query': "Ayman Mohamed Abdallah's projects"}, 'id': 'c8d6e8f1-a26f-423d-9d45-63825375d020', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1573, 'output_tokens': 161, 'total_tokens': 1734, 'input_token_details': {'cache_read': 794}, 'output_token_details': {'reasoning': 116}}),
# ...

# %%
state3["messages"][-3: ]
# Out:
# [HumanMessage(content='which college ayman graduted from?', additional_kwargs={}, response_metadata={}, id='bd8bcd13-ddd1-4f46-9ee8-b3874bb0ebd0'),
#  AIMessage(content='', additional_kwargs={'function_call': {'name': 'search_docs', 'arguments': '{"query": "Ayman Mohamed college"}'}, '__gemini_function_call_thought_signatures__': {'d56ec740-94d9-4e14-950a-07230397f6e1': '...'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019cc5cc-7337-7d71-ab64-1a12c2c05477-0', tool_calls=[{'name': 'search_docs', 'args': {'query': 'Ayman Mohamed college'}, 'id': 'd56ec740-94d9-4e14-950a-07230397f6e1', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1572, 'output_tokens': 110, 'total_tokens': 1682, 'input_token_details': {'cache_read': 794}, 'output_token_details': {'reasoning': 92}}),
# ...

# %%
initial_state = {'messages': [HumanMessage(content='from which college that ayman graduate', additional_kwargs={}, response_metadata={}), AIMessage(content='Ayman Mohamed graduated with a B.Sc. in Computer Science from Menoufia University.\n\n*   **University**: Menoufia University\n*   **Degree**: B.Sc. in Computer Science\n*   **Faculty**: Menof Electronics Engineering\n*   **Period**: 2019 – 2024\n*   **Graduation Grade**: Very Good\n\n📂 Source: Ayman_Mohamed_AI_Engineer_CV.pdf', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='give me all users info with role name ', additional_kwargs={}, response_metadata={}), AIMessage(content="The system executed a SQL query to retrieve user information along with their respective role names. No specific user data was returned in the system's response.\n\nNo relevant information found in the system.\n\n🔍 SQL Query Executed: `SELECT u.*, r.name AS role_name FROM users u JOIN roles r ON u.role_id = r.id`", additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='which deparments we have ', additional_kwargs={}, response_metadata={}), AIMessage(content='Here is the list of departments currently registered in the system.\n\n| **Department Name** |\n|---------------------|\n| Engineering         |\n| Finance             |\n| HR                  |\n| Sales               |\n| Operations          |\n| Legal               |\n\n🔍 SQL Query Executed: `SELECT name FROM departments`', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='give me all users info with role name ', additional_kwargs={}, response_metadata={}), AIMessage(content='The following table provides a complete list of all users, including their associated roles and technical details.\n\n| **id** | **name** | **email** | **api_key** | **is_active** | **created_at** | **role_id** | **role_name** |\n|--------|----------|------------------------|--------------------|---------------|----------------------------|-------------|---------------|\n| 5      | Sayed    | user4@enterprise.com   | enterprise-key-4   | True          | 2026-02-18 16:45:47.646660 | 1           | admin         |\n| 4      | Ali      | user3@enterprise.com   | enterprise-key-3   | True          | 2026-02-18 16:45:47.646658 | 3           | analyst       |\n| 3      | Mohamed  | user2@enterprise.com   | enterprise-key-2   | True          | 2026-02-18 16:45:47.646656 | 3           | analyst       |\n| 2      | Ahemd    | user1@enterprise.com   | enterprise-key-1   | True          | 2026-02-18 16:45:47.646654 | 4           | viewer        |\n| 1      | Ayman    | user0@enterprise.com   | enterprise-key-0   | True          | 2026-02-18 16:45:47.646647 | 4           | viewer        |\n\n🔍 SQL Query Executed: `SELECT u.*, r.name AS role_name FROM users u JOIN roles r ON u.role_id = r.id`', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='give me number of eamployess in each department', additional_kwargs={}, response_metadata={}), AIMessage(content='Here is the number of employees in each department:\n\n| **Department Name** | **Number of Employees** |\n|---------------------|-------------------------|\n| Engineering         | 4                       |\n| Operations          | 6                       |\n| Legal               | 8                       |\n| Finance             | 2                       |\n| Sales               | 8                       |\n| HR                  | 2                       |\n\n🔍 SQL Query Executed:\n```sql\nSELECT d.name AS department_name, COUNT(e.id) AS number_of_employees\nFROM departments d\nLEFT JOIN employees e ON d.id = e.department_id\nGROUP BY d.name\n```', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content="what's thier full info", additional_kwargs={}, response_metadata={})], 'user_role': 'admin', 'db': <sqlalchemy.orm.session.Session object at 0x7b89294e8a90>}
