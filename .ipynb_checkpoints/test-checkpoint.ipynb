# %%
from langchain_google_genai import ChatGoogleGenerativeAI
# Out:
# Running cells with 'agentic-rag (3.13.7) (Python 3.13.7)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'd:/AI-2025/Systems/enterprise-knowledge-agent/agentic-rag/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
# creat llm
llm = ChatGoogleGenerativeAI(
        model="gemini-2.5-flash",
        temperature=0,
        google_api_key=None 
    )
